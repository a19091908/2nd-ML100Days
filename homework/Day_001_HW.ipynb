# %% [markdown]
# # 作業1：
# ###### 我選擇的DataSet是「Urban Sound Classification」
# - Kaggle：https://www.kaggle.com/pavansanagapati/urban-sound-classification
# - 計畫網站：https://urbansounddataset.weebly.com/
# - 大學相關論文：http://www.justinsalamon.com/uploads/4/3/9/4/4394963/salamon_urbansound_acmmm14.pdf
# ---
# ###### 1. 你選的這組資料為何重要
#  - 提供政府以非人工方式評估哪些地方的噪音優先被改善。
#
# ###### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#  - 聲音檔來源：www.freesound.org
#  - 聲音由網友協助標記
#
# ###### 3. 蒐集而來的資料型態為何
#  - 結構化資料：ID、Class
#  - 非結構化資料：聲音
#
# ###### 4. 這組資料想解決的問題如何評估
#  - 聲音預測正確率。

# %% [markdown]
# ### 作業2：
#
# ###### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ---
# ###### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# - 為提高載客量，預測各時間點駕駛附近使用者可能出現的位置，以提升載客機率而提升業績。
# - 假設使用者開啟叫車軟體代表使用者想要叫車。
# ###### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# - 使用者開啟叫車軟體時的座標位置。
# ###### 3. 蒐集而來的資料型態為何
# - 結構化資料：座標(經緯度)、開啟軟體時間。
# ###### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ###  $ \frac{確實有叫車人數}{打開叫車軟體人數} $

# %% [markdown]
# # 作業3：
#
# ### 請寫一個函式用來計算 Mean Square Error
#
# ### $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y);
    return mse;

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.035
# The Mean absolute error is 11.569
